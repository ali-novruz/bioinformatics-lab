# %% [markdown]
# # VCF-i sahə-sahə şərh etmək
#
# Bu notebook bir wrapper deyil: hər mərhələdə ara nəticə, fərziyyə və yoxlama sualı görünür.

# %% [markdown]
# ## Öyrənmə məqsədi
#
# Məlumat strukturunu oxumaq, hesablamanı kiçik nümunədə görmək, nəticə ilə iddia arasındakı sərhədi yazmaq.

# %%
from pathlib import Path
ROOT=Path.cwd()
print('repo:',ROOT.name)
# Out:
# repo: bioinformatics-lab

# %% [markdown]
# ## 1. VCF sətrinin anatomiyası
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
line='chr1\t10\t.\tA\tG\t60\tPASS\tDP=20\tGT:AD\t0/1:10,10'
line.split('\t')
# Out:
# ['chr1', '10', '.', 'A', 'G', '60', 'PASS', 'DP=20', 'GT:AD', '0/1:10,10']

# %% [markdown]
# **Özünü yoxla:** INFO və FORMAT hansı səviyyələrdə məlumat saxlayır?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 2. Parser ilə oxumaq
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from pathlib import Path
from biolab.io import read_vcf
p=Path('datasets/fixtures/toy.vcf')
records=list(read_vcf(p));len(records),records[0]
# Out:
# (4,
#  {'chrom': 'toy',
#   'pos': 5,
#   'id': '.',
#   'ref': 'A',
#   'alts': ('G',),
#   'qual': 50.0,
#   'filter': 'PASS',
#   'info': {},
#   'samples': {'s1': {'GT': '0/1'}, 's2': {'GT': '1/1'}}})

# %% [markdown]
# **Özünü yoxla:** Parser hansı yanlış başlıqları rədd etməlidir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 3. Variant tipi
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.genomics import variant_type
[(r,a,variant_type(r,a)) for r,a in [('A','G'),('A','AT'),('AC','GT')]]
# Out:
# [('A', 'G', 'SNV'), ('A', 'AT', 'indel'), ('AC', 'GT', 'MNV')]

# %% [markdown]
# **Özünü yoxla:** Eyni uzunluqlu iki bazalı dəyişiklik niyə SNV deyil?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 4. Genotipdən allel sayı
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.genomics import allele_counts
allele_counts({'s1':{'GT':'0/1'},'s2':{'GT':'1/1'}},1)
# Out:
# [1, 3]

# %% [markdown]
# **Özünü yoxla:** Missing allel tezliyi hansı məxrəclə hesablanmalıdır?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 5. Keyfiyyət filtrinin təsiri
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.genomics import analyze_vcf
table,summary=analyze_vcf(p,min_qual=20);summary
# Out:
# {'input_records': 4,
#  'retained_alleles': 4,
#  'excluded_records': {'not_PASS': 1},
#  'types': {'SNV': 3, 'indel': 1},
#  'transitions': 2,
#  'transversions': 1,
#  'ti_tv': 2.0,
#  'min_qual': 20,
#  'require_PASS': True}

# %% [markdown]
# **Özünü yoxla:** QUAL həddi klinik patogenlik deməkdirmi?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 6. Çox-allelli qeyd
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
allele_counts({'s1':{'GT':'1/2'},'s2':{'GT':'0/2'}},2)
# Out:
# [1, 1, 2]

# %% [markdown]
# **Özünü yoxla:** Normalization zamanı çox-allelli qeyd niyə ayrıla bilər?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 7. Sərhəd cümləsi
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
claim='Bu analiz təsviri filtrdir; klinik təsnifat deyil.'
claim
# Out:
# 'Bu analiz təsviri filtrdir; klinik təsnifat deyil.'

# %% [markdown]
# **Özünü yoxla:** Patogenlik üçün hansı əlavə sübut növləri lazımdır?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.
