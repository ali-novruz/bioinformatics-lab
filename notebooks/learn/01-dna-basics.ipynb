# %% [markdown]
# # DNA ardıcıllığını addım-addım oxumaq
#
# Bu notebook bir wrapper deyil: hər mərhələdə ara nəticə, fərziyyə və yoxlama sualı görünür.

# %% [markdown]
# ## Öyrənmə məqsədi
#
# Məlumat strukturunu oxumaq, hesablamanı kiçik nümunədə görmək, nəticə ilə iddia arasındakı sərhədi yazmaq.

# %%
from pathlib import Path
ROOT=Path.cwd()
print('repo:',ROOT.name)
# Out:
# repo: bioinformatics-lab

# %% [markdown]
# ## 1. Simvollar və təmizləmə
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sequence import clean_dna
raw=' acgt nry '
clean_dna(raw)
# Out:
# 'ACGTNRY'

# %% [markdown]
# **Özünü yoxla:** Boşluq və kiçik hərflər nəticəyə niyə təsir etməməlidir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 2. Baza sayları
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from collections import Counter
seq=clean_dna(raw)
Counter(seq)
# Out:
# Counter({'A': 1, 'C': 1, 'G': 1, 'T': 1, 'N': 1, 'R': 1, 'Y': 1})

# %% [markdown]
# **Özünü yoxla:** N və R kimi qeyri-müəyyən simvolları ayrıca niyə sayırıq?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 3. GC payı
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sequence import gc_content
gc_content('AAGCGTNN')
# Out:
# 0.5

# %% [markdown]
# **Özünü yoxla:** Məxrəcə N daxil edilsə qiymət hansı istiqamətdə qərəzli olar?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 4. Tərs komplement
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sequence import reverse_complement
reverse_complement('ATGCCN')
# Out:
# 'NGGCAT'

# %% [markdown]
# **Özünü yoxla:** Sequencer digər strand-i oxusa bu əməliyyat nəyi bərpa edir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 5. Kodlar və çərçivə
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
seq='ATGAAATAGCC'
[seq[i:i+3] for i in range(0,len(seq)-2,3)]
# Out:
# ['ATG', 'AAA', 'TAG']

# %% [markdown]
# **Özünü yoxla:** Bir baza əlavə olunanda bütün sonrakı kodonlar niyə dəyişir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 6. Motifin üst-üstə düşməsi
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sequence import motif_positions
motif_positions('AAAAA','AAA')
# Out:
# [0, 1, 2]

# %% [markdown]
# **Özünü yoxla:** Adi string count burada niyə səhv cavab verə bilər?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 7. Yekun audit
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sequence import sequence_summary
sequence_summary('ATGAAATAGNN')
# Out:
# {'length': 11,
#  'counts': {'A': 5, 'T': 2, 'G': 2, 'N': 2},
#  'gc_fraction_acgt_only': 0.2222222222222222,
#  'ambiguous_bases': 2,
#  'rna': 'AUGAAAUAGNN',
#  'reverse_complement': 'NNCTATTTCAT',
#  'frame0_codons': {'ATG': 1, 'AAA': 1, 'TAG': 1},
#  'untranslated_tail': 2}

# %% [markdown]
# **Özünü yoxla:** Hansı sahələr müşahidədir, hansılar bioloji şərh tələb edir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.
