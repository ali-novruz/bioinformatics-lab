# %% [markdown]
# # Nəticəni sınayan nəzarətlər
#
# Bu notebook bir wrapper deyil: hər mərhələdə ara nəticə, fərziyyə və yoxlama sualı görünür.

# %% [markdown]
# ## Öyrənmə məqsədi
#
# Məlumat strukturunu oxumaq, hesablamanı kiçik nümunədə görmək, nəticə ilə iddia arasındakı sərhədi yazmaq.

# %%
from pathlib import Path
ROOT=Path.cwd()
print('repo:',ROOT.name)
# Out:
# repo: bioinformatics-lab

# %% [markdown]
# ## 1. İddianı yazmaq
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
claim={'observation':'model score is high','claim':'signal generalizes','alternative':'leakage or small-sample variance'};claim
# Out:
# {'observation': 'model score is high',
#  'claim': 'signal generalizes',
#  'alternative': 'leakage or small-sample variance'}

# %% [markdown]
# **Özünü yoxla:** Observation ilə causal claim arasında hansı körpü çatmır?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 2. Data split sərhədi
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
train=set(range(8));test=set(range(8,10));train.isdisjoint(test)
# Out:
# True

# %% [markdown]
# **Özünü yoxla:** Feature selection hansı tərəfdə aparılmalıdır?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 3. Permutation p-value
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sensitivity import permutation_pvalue
permutation_pvalue(.9,[.3,.4,.5,.6,.7,.8,.2,.1,.45])
# Out:
# 0.1

# %% [markdown]
# **Özünü yoxla:** Niyə numerator və denominator-a bir əlavə olunur?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 4. Singleton GO control
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sensitivity import singleton_enrichment
singleton_enrichment(range(10),{'termA':{0,1},'termB':{2,3,4}},min_size=2).head()
# Out:
#    gene_id  min_pvalue  min_padj  discoveries  tested_terms
# 0        0         0.2       0.4            0             2
# 1        1         0.2       0.4            0             2
# 2        2         0.3       0.6            0             2
# 3        3         0.3       0.6            0             2
# 4        4         0.3       0.6            0             2

# %% [markdown]
# **Özünü yoxla:** Family eyni saxlanmasa control nəyi dəyişmiş olar?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 5. Sensitivity analysis
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
import numpy as np
thresholds=[.3,.5,.7];prob=np.array([.2,.4,.6,.8]);[(t,int((prob>=t).sum())) for t in thresholds]
# Out:
# [(0.3, 3), (0.5, 2), (0.7, 1)]

# %% [markdown]
# **Özünü yoxla:** Nəticə bir threshold-da kəskin dəyişirsə necə hesabat verərsiniz?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 6. Reproduksiya qeydi
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from pathlib import Path
required=['inputs','parameters','software','outputs','limitations'];required
# Out:
# ['inputs', 'parameters', 'software', 'outputs', 'limitations']

# %% [markdown]
# **Özünü yoxla:** Hash mənanı yoxsa yalnız byte bütövlüyünü sübut edir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 7. Qərar matrisi
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
import pandas as pd
pd.DataFrame([['positive','repeat'],['negative','report boundary'],['unstable','collect data']],columns=['control','next_step'])
# Out:
#     control        next_step
# 0  positive           repeat
# 1  negative  report boundary
# 2  unstable     collect data

# %% [markdown]
# **Özünü yoxla:** Mənfi nəticəni findings jurnalına yazmaq niyə dəyərlidir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.
