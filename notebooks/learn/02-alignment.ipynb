# %% [markdown]
# # Alignment matrisi və traceback
#
# Bu notebook bir wrapper deyil: hər mərhələdə ara nəticə, fərziyyə və yoxlama sualı görünür.

# %% [markdown]
# ## Öyrənmə məqsədi
#
# Məlumat strukturunu oxumaq, hesablamanı kiçik nümunədə görmək, nəticə ilə iddia arasındakı sərhədi yazmaq.

# %%
from pathlib import Path
ROOT=Path.cwd()
print('repo:',ROOT.name)
# Out:
# repo: bioinformatics-lab

# %% [markdown]
# ## 1. Skor modelini yazmaq
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
match,mismatch,gap=2,-1,-2
{'match':match,'mismatch':mismatch,'gap':gap}
# Out:
# {'match': 2, 'mismatch': -1, 'gap': -2}

# %% [markdown]
# **Özünü yoxla:** Gap opening və extension ayrı olsa hansı model dəyişir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 2. Birinci sətir və sütun
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
import numpy as np
m=np.zeros((5,4));m[:,0]=np.arange(5)*gap;m[0,:]=np.arange(4)*gap
m
# Out:
# array([[ 0., -2., -4., -6.],
#        [-2.,  0.,  0.,  0.],
#        [-4.,  0.,  0.,  0.],
#        [-6.,  0.,  0.,  0.],
#        [-8.,  0.,  0.,  0.]])

# %% [markdown]
# **Özünü yoxla:** Lokal alignment-də bu sərhədlər niyə sıfır qalır?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 3. Bir hüceyrənin recurrence-i
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
diag,up,left=3+match,1+gap,2+gap
max(diag,up,left)
# Out:
# 5

# %% [markdown]
# **Özünü yoxla:** Bərabərlik olduqda tie-break nəticə ardıcıllığını necə dəyişə bilər?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 4. Qlobal uyğunlaşdırma
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
from biolab.sequence import align
a=align('ACGT','AGT','global');a.to_dict()
# Out:
# {'query': 'ACGT',
#  'target': 'A-GT',
#  'score': 4.0,
#  'query_start': 0,
#  'query_end': 4,
#  'target_start': 0,
#  'target_end': 3,
#  'mode': 'global',
#  'identity_all_alignment_columns': 0.75}

# %% [markdown]
# **Özünü yoxla:** Skor və identity eyni keyfiyyət ölçüsüdürmü?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 5. Lokal uyğunlaşdırma
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
align('TTACGTAA','ACG','local').to_dict()
# Out:
# {'query': 'ACG',
#  'target': 'ACG',
#  'score': 6.0,
#  'query_start': 2,
#  'query_end': 5,
#  'target_start': 0,
#  'target_end': 3,
#  'mode': 'local',
#  'identity_all_alignment_columns': 1.0}

# %% [markdown]
# **Özünü yoxla:** Başlanğıc və son koordinatların half-open olması nə verir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 6. Backend uyğunluğu
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
p=align('ACGTAC','ACTAC',backend='python');n=align('ACGTAC','ACTAC',backend='numpy');p==n
# Out:
# True

# %% [markdown]
# **Özünü yoxla:** Sürətli yolun eyni tie siyasətini saxlaması niyə vacibdir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.

# %% [markdown]
# ## 7. Limit və istehsal alətləri
#
# Əvvəl kiçik və görünən nümunədə mexanizmi yoxlayın; sonra böyük layihə çıxışına keçin.

# %%
cells=(1500+1)*(1500+1)
{'cells':cells,'within_teaching_limit':cells<=4_000_000}
# Out:
# {'cells': 2253001, 'within_teaching_limit': True}

# %% [markdown]
# **Özünü yoxla:** Uzun genom üçün niyə BWA/minimap2 kimi indeksli alət seçilir?
#
# Cavabınızı bir cümləlik fərziyyə və onu sınayan bir əmrlə yazın.
